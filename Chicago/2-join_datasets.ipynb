# %%
import pandas as pd

# %% [markdown]
# # Read Quantitative Data

# %%
df = pd.read_csv('cleaned_data/quant_features.csv')
df.head()
# Out:
#          community   shape_area  area_num_1    shape_len  2000_POP  2010_POP  \
# 0          DOUGLAS  46004621.16          35  31027.05451     26470     18238
# 1          OAKLAND  16913961.04          36  19565.50615      6110      5918
# 2      FULLER PARK  19916704.87          37  25339.08975      3420      2876
# 3  GRAND BOULEVARD  48492503.16          38  28196.83716     28006     21929
# 4          KENWOOD  29071741.93          39  23325.16791     18363     17841
#
#    TOT_POP     UND19    A20_34    A35_49  ...  Childhood Lead Poisoning  \
# 0    20781  0.212309  0.310813  0.172465  ...                     0.000
# 1     6645  0.333333  0.184349  0.233860  ...                     0.003
# 2     2439  0.161132  0.193522  0.148421  ...                     0.025
# 3    22313  0.264823  0.193251  0.216959  ...                     0.010
# 4    17189  0.184420  0.275816  0.184886  ...                     0.004
#
# ...

# %%
df.shape
# Out:
# (77, 111)

# %% [markdown]
# # Read Qualitative Data

# %%
df2 = pd.read_csv('cleaned_data/airbnb.csv')
df2.head()
# Out:
#   neighborhood_id  accessible  activities   african   airport   amazing  \
# 0     Albany Park    0.042857         0.0  0.014286  0.071429  0.057143
# 1  Archer Heights    0.000000         0.0  0.000000  0.000000  0.000000
# 2   Armour Square    0.017241         0.0  0.000000  0.000000  0.000000
# 3         Ashburn    0.000000         0.0  0.000000  0.555556  0.000000
# 4  Auburn Gresham    0.000000         0.0  0.000000  0.000000  0.000000
#
#    american  aquarium  architecture       art  ...      wine  winning  \
# 0  0.057143       0.0      0.014286  0.014286  ...  0.071429      0.0
# 1  0.000000       0.0      0.000000  0.000000  ...  0.000000      0.0
# 2  0.000000       0.0      0.000000  0.103448  ...  0.000000      0.0
# 3  0.000000       0.0      0.000000  0.000000  ...  0.000000      0.0
# 4  0.000000       0.0      0.000000  0.000000  ...  0.000000      0.0
#
#    wonderful  work   working     world     young  zoo  num_listings  \
# ...

# %%
df2.neighborhood_id = df2.neighborhood_id.str.upper()
df2.head()
# Out:
#   neighborhood_id  accessible  activities   african   airport   amazing  \
# 0     ALBANY PARK    0.042857         0.0  0.014286  0.071429  0.057143
# 1  ARCHER HEIGHTS    0.000000         0.0  0.000000  0.000000  0.000000
# 2   ARMOUR SQUARE    0.017241         0.0  0.000000  0.000000  0.000000
# 3         ASHBURN    0.000000         0.0  0.000000  0.555556  0.000000
# 4  AUBURN GRESHAM    0.000000         0.0  0.000000  0.000000  0.000000
#
#    american  aquarium  architecture       art  ...      wine  winning  \
# 0  0.057143       0.0      0.014286  0.014286  ...  0.071429      0.0
# 1  0.000000       0.0      0.000000  0.000000  ...  0.000000      0.0
# 2  0.000000       0.0      0.000000  0.103448  ...  0.000000      0.0
# 3  0.000000       0.0      0.000000  0.000000  ...  0.000000      0.0
# 4  0.000000       0.0      0.000000  0.000000  ...  0.000000      0.0
#
#    wonderful  work   working     world     young  zoo  num_listings  \
# ...

# %%
df2.shape
# Out:
# (73, 290)

# %%
df3 = pd.read_csv('cleaned_data/foursquare.csv')
df3.head()
# Out:
#      Neighborhood  ATM  Accessories Store  Adult Boutique  Afghan Restaurant  \
# 0     ALBANY PARK  0.0                0.0             0.0               0.01
# 1  ARCHER HEIGHTS  0.0                0.0             0.0               0.00
# 2   ARMOUR SQUARE  0.0                0.0             0.0               0.00
# 3         ASHBURN  0.0                0.0             0.0               0.00
# 4  AUBURN GRESHAM  0.0                0.0             0.0               0.00
#
#    African Restaurant  Airport  Airport Food Court  Airport Lounge  \
# 0                0.00     0.00                0.00             0.0
# 1                0.00     0.01                0.01             0.0
# 2                0.01     0.00                0.00             0.0
# 3                0.00     0.00                0.00             0.0
# 4                0.00     0.00                0.00             0.0
#
#    Airport Service  ...  Volleyball Court  Warehouse  Warehouse Store  \
# ...

# %% [markdown]
# # Merge Datasets on Unique Identifier

# %%
merged = pd.merge(df,df2,left_on='community', right_on = 'neighborhood_id', how = "left")
merged = pd.merge(merged,df3,left_on='community_x', right_on = 'Neighborhood', how = "left")
merged.head()
# Out:
#        community_x   shape_area  area_num_1    shape_len  2000_POP  2010_POP  \
# 0          DOUGLAS  46004621.16          35  31027.05451     26470     18238
# 1          OAKLAND  16913961.04          36  19565.50615      6110      5918
# 2      FULLER PARK  19916704.87          37  25339.08975      3420      2876
# 3  GRAND BOULEVARD  48492503.16          38  28196.83716     28006     21929
# 4          KENWOOD  29071741.93          39  23325.16791     18363     17841
#
#    TOT_POP     UND19    A20_34    A35_49  ...  Volleyball Court  Warehouse  \
# 0    20781  0.212309  0.310813  0.172465  ...               0.0        0.0
# 1     6645  0.333333  0.184349  0.233860  ...               0.0        0.0
# 2     2439  0.161132  0.193522  0.148421  ...               0.0        0.0
# 3    22313  0.264823  0.193251  0.216959  ...               0.0        0.0
# 4    17189  0.184420  0.275816  0.184886  ...               0.0        0.0
#
# ...

# %% [markdown]
# # Drop Duplicate Column and Split Qualitative/Quantitative Features

# %%
print(merged.columns.tolist())
# Out:
# ['community_x', 'shape_area', 'area_num_1', 'shape_len', '2000_POP', '2010_POP', 'TOT_POP', 'UND19', 'A20_34', 'A35_49', 'A50_64', 'A65_74', 'A75_84', 'OV85', 'MED_AGE', 'WHITE', 'HISP', 'BLACK', 'ASIAN', 'OTHER', 'POP_16OV', 'IN_LBFRC', 'EMP', 'UNEMP', 'NOT_IN_LBFRC', 'WORK_AT_HOME', 'TOT_COMM', 'POP_25OV', 'LT_HS', 'HS', 'SOME_COLL', 'ASSOC', 'BACH', 'GRAD_PROF', 'INC_LT_25K', 'INC_25_50K', 'INC_50_75K', 'INC_75_100K', 'INC_100_150K', 'INC_GT_150', 'MEDINC', 'TOT_HH', 'OWN_OCC_HU', 'RENT_OCC_HU', 'VAC_HU', 'HU_TOT', 'HV_LT_150K', 'HV_150_300K', 'HV_300_500K', 'HV_GT_500K', 'MED_HV', 'AVG_VMT', 'OPEN_SPACE_PER_1000', 'Sfperc', 'Mfperc', 'MIXperc', 'COMMperc', 'INSTperc', 'INDperc', 'TRANSperc', 'Agperc', 'OPENperc', 'VACperc', 'NATIVE', 'FOR_BORN', 'POP_OV5', 'ONLY_ENGLISH', 'NOT_ENGLISH', 'LING_ISO', 'ENGLISH', 'SPANISH', 'SLAVIC', 'CHINESE', 'TAGALOG', 'ARABIC', 'KOREAN', 'OTHER_ASIAN', 'OTHER_EURO', 'OTHER_UNSPEC', 'highly_walkable_pop_pct', 'highly_walkable_emp_pct', 'assoc_plus
# ...

# %%
merged.drop(['Neighborhood','neighborhood_id'],axis=1,inplace=True)
merged.shape
# Out:
# (77, 722)

# %%
# move example neighborhood/neighborhood to beginning
col = merged.pop("community_x")
merged.insert(0, col.name, col)

# %%
merged= merged.rename({"community_x": "neighborhood_id"}, axis=1)

# %%
merged.columns[111]
# Out:
# 'accessible'

# %%
merged.columns[272]
# Out:
# 'little'

# %%
merged.columns[628]
# Out:
# 'Pie Shop'

# %% [markdown]
# - merged[0:2] are neighborhood IDs/names
# - merged[2:216] are qualitative features
# - merged[216:628] are foursquare features
# - merged[628:] are quantitative features

# %% [markdown]
# # Write Output File

# %%
merged.to_csv('cleaned_data/merged.csv',index=False)

# %%
print(merged.neighborhood_id.to_list())
# Out:
# ['DOUGLAS', 'OAKLAND', 'FULLER PARK', 'GRAND BOULEVARD', 'KENWOOD', 'LINCOLN SQUARE', 'WASHINGTON PARK', 'HYDE PARK', 'WOODLAWN', 'ROGERS PARK', 'JEFFERSON PARK', 'FOREST GLEN', 'NORTH PARK', 'ALBANY PARK', 'PORTAGE PARK', 'IRVING PARK', 'DUNNING', nan, 'BELMONT CRAGIN', 'WEST RIDGE', 'HERMOSA', 'AVONDALE', 'LOGAN SQUARE', 'HUMBOLDT PARK', 'WEST TOWN', 'AUSTIN', 'WEST GARFIELD PARK', 'EAST GARFIELD PARK', 'NEAR WEST SIDE', 'NORTH LAWNDALE', 'UPTOWN', 'SOUTH LAWNDALE', 'LOWER WEST SIDE', 'NEAR SOUTH SIDE', 'ARMOUR SQUARE', 'NORWOOD PARK', 'NEAR NORTH SIDE', 'LOOP', 'SOUTH SHORE', 'CHATHAM', 'AVALON PARK', 'SOUTH CHICAGO', nan, 'MCKINLEY PARK', 'LAKE VIEW', 'CALUMET HEIGHTS', 'ROSELAND', 'NORTH CENTER', 'PULLMAN', 'SOUTH DEERING', nan, nan, 'RIVERDALE', 'HEGEWISCH', 'GARFIELD RIDGE', 'ARCHER HEIGHTS', 'BRIGHTON PARK', 'BRIDGEPORT', 'NEW CITY', 'WEST ELSDON', 'GAGE PARK', 'CLEARING', 'WEST LAWN', 'CHICAGO LAWN', 'WEST ENGLEWOOD', 'ENGLEWOOD', 'GREATER GRAND CROSSING', 'LINCOLN PARK', 'A
# ...
